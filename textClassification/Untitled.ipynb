# %%
import pandas as pd

# %%
df_alldata = pd.read_csv("./data/allData.csv")

# %%
df_validdata = pd.read_csv("./data/validData.csv")

# %%
print df_alldata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 399 entries, 0 to 398
# Data columns (total 9 columns):
# name       399 non-null object
# context    399 non-null object
# code       399 non-null float64
# level      399 non-null float64
# type       399 non-null object
# text       399 non-null object
# extract    399 non-null object
# rel        399 non-null object
# year       399 non-null object
# dtypes: float64(2), object(7)
# memory usage: 28.1+ KB
# None

# %%
print df_validdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 399 entries, 0 to 398
# Data columns (total 5 columns):
# name       399 non-null object
# context    399 non-null object
# type       399 non-null object
# extract    399 non-null object
# rel        399 non-null object
# dtypes: object(5)
# memory usage: 15.7+ KB
# None

# %%
print df_alldata
# Out:
#             name            context      code  level              type  \
# 0             随县         [湖北省, 随州市]  421321.0    3.0               add
# 1            南汇区         [上海市, 南汇区]  310119.0    2.0               del
# 2            塘沽区         [天津市, 塘沽区]  120107.0    2.0               del
# 3            汉沽区         [天津市, 汉沽区]  120108.0    2.0               del
# 4            大港区         [天津市, 大港区]  120109.0    2.0               del
# 5           红寺堡区     [宁夏回族自治区, 吴忠市]  640303.0    3.0               add
# 6            通州区         [江苏省, 南通市]  320612.0    3.0               add
# 7            通州市         [江苏省, 南通市]  320683.0    3.0               del
# 8           滨海新区        [天津市, 滨海新区]  120116.0    2.0               add
# 9           八道江区         [吉林省, 白山市]  220602.0    3.0  just_name_change
# 10           铜山区         [江苏省, 徐州市]  320312.0    3.0               add
# 11           宣武区         [北京市, 宣武区]  110104.0    2.0               del
# ...

# %%
for index, df_data in df_alldata.iterrows():
    print df_data
# Out:
# name                                                      随县
# context                                           [湖北省, 随州市]
# code                                                  421321
# level                                                      3
# type                                                     add
# text       随县历史沿革编辑随县以西周封国随为名，春秋时分属随、厉、唐三国，战国时属楚。公元前221年，...
# extract    2009年，随县获国务院批准重新设立，即在现随州市曾都区（市政府所在地）区划范围内，划出19...
# rel                                                      新增县
# year                                               2008-2009
# Name: 0, dtype: object
# name                                                     南汇区
# context                                           [上海市, 南汇区]
# code                                                  310119
# level                                                      2
# type                                                     del
# text       南汇区历史沿革编辑南汇是长江三角洲冲积平原的一部分，是上海市郊成陆较晚的地区。 据《旧唐书》...
# ...
